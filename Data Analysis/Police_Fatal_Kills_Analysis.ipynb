# %% [markdown]
# # Introduction

# %% [markdown]
# <center><img src=https://i.imgur.com/sX3K62b.png></center>
#
# Since Jan. 1, 2015, [The Washington Post](https://www.washingtonpost.com/) has been compiling a database of every fatal shooting in the US by a police officer in the line of duty.
# While there are many challenges regarding data collection and reporting, The Washington Post has been tracking more than a dozen details about each killing. This includes the race, age and gender of the deceased, whether the person was armed, and whether the victim was experiencing a mental-health crisis. The Washington Post has gathered this supplemental information from law enforcement websites, local new reports, social media, and by monitoring independent databases such as "Killed by police" and "Fatal Encounters". The Post has also conducted additional reporting in many cases.
#
# There are 4 additional datasets: US census data on poverty rate, high school graduation rate, median household income, and racial demographics. [Source of census data](https://factfinder.census.gov/faces/nav/jsf/pages/community_facts.xhtml).

# %% [markdown]
# ### Upgrade Plotly

# %%
# %pip install --upgrade plotly
# %pip install -U kaleido
# Out:
# Requirement already satisfied: plotly in c:\users\simran\anaconda3\lib\site-packages (5.2.2)
# Requirement already satisfied: six in c:\users\simran\anaconda3\lib\site-packages (from plotly) (1.15.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\simran\anaconda3\lib\site-packages (from plotly) (7.0.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: kaleido in c:\users\simran\anaconda3\lib\site-packages (0.2.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import plotly.io as pio
pio.renderers.default = "svg"

# %% [markdown]
# ## Import Statements

# %%
import numpy as np
import pandas as pd
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns

from datetime import datetime
from collections import Counter

# %% [markdown]
# ## Notebook Presentation

# %%
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# ## Load the Data

# %%
df_hh_income = pd.read_csv('Median_Household_Income_2015.csv', encoding="windows-1252") # Household Income
df_pct_poverty = pd.read_csv('Pct_People_Below_Poverty_Level.csv', encoding="windows-1252") # Poverty Rate
df_pct_completed_hs = pd.read_csv('Pct_Over_25_Completed_High_School.csv', encoding="windows-1252") # High School Completed
df_share_race_city = pd.read_csv('Share_of_Race_By_City.csv', encoding="windows-1252") # Race(black,white etc) share in City
df_fatalities = pd.read_csv('Deaths_by_Police_US.csv', encoding="windows-1252") # Kill cases by Police

# %%
df_hh_income.head()
# Out:
#   Geographic Area             City Median Income
# 0              AL       Abanda CDP         11207
# 1              AL   Abbeville city         25615
# 2              AL  Adamsville city         42575
# 3              AL     Addison town         37083
# 4              AL       Akron town         21667

# %%
df_pct_poverty.head()
# Out:
#   Geographic Area             City poverty_rate
# 0              AL       Abanda CDP         78.8
# 1              AL   Abbeville city         29.1
# 2              AL  Adamsville city         25.5
# 3              AL     Addison town         30.7
# 4              AL       Akron town           42

# %%
df_pct_completed_hs
# Out:
#       Geographic Area                    City percent_completed_hs
# 0                  AL              Abanda CDP                 21.2
# 1                  AL          Abbeville city                 69.1
# 2                  AL         Adamsville city                 78.9
# 3                  AL            Addison town                 81.4
# 4                  AL              Akron town                 68.6
# ...               ...                     ...                  ...
# 29324              WY  Woods Landing-Jelm CDP                  100
# 29325              WY            Worland city                 85.6
# 29326              WY             Wright town                 89.2
# 29327              WY              Yoder town                 79.4
# 29328              WY           Y-O Ranch CDP                  100
#
# [29329 rows x 3 columns]

# %%
df_share_race_city
# Out:
#       Geographic area                    City  share_white  share_black  \
# 0                  AL              Abanda CDP        67.20        30.20
# 1                  AL          Abbeville city        54.40        41.40
# 2                  AL         Adamsville city        52.30        44.90
# 3                  AL            Addison town        99.10         0.10
# 4                  AL              Akron town        13.20        86.50
# ...               ...                     ...          ...          ...
# 29261              WY  Woods Landing-Jelm CDP        95.90         0.00
# 29262              WY            Worland city        89.90         0.30
# 29263              WY             Wright town        94.50         0.10
# 29264              WY              Yoder town        97.40         0.00
# 29265              WY           Y-O Ranch CDP        92.80         1.50
#
#        share_native_american  share_asian  share_hispanic
# 0                       0.00         0.00            1.60
# 1                       0.10         1.00            3.10
# 2                       0.50         0.30            2.30
# 3                       0.00         0.10            0.40
# 4                       0.00         0.00            0.30
# ...                      ...          ...             ...
# 29261                   0.00         2.10            0.00
# 29262                   1.30         0.60           16.60
# 29263                   1.40         0.20            6.20
# 29264                   0.00         0.00            4.00
# 29265                   2.60         0.00           11.80
#
# [29266 rows x 7 columns]

# %%
df_fatalities
# Out:
#         id                name      date   manner_of_death       armed   age  \
# 0        3          Tim Elliot  2/1/2015              shot         gun 53.00
# 1        4    Lewis Lee Lembke  2/1/2015              shot         gun 47.00
# 2        5  John Paul Quintero  3/1/2015  shot and Tasered     unarmed 23.00
# 3        8     Matthew Hoffman  4/1/2015              shot  toy weapon 32.00
# 4        9   Michael Rodriguez  4/1/2015              shot    nail gun 39.00
# ...    ...                 ...       ...               ...         ...   ...
# 2530  2822    Rodney E. Jacobs  28/07/17              shot         gun 31.00
# 2531  2813               TK TK  28/07/17              shot     vehicle   NaN
# 2532  2818  Dennis W. Robinson  29/07/17              shot         gun 48.00
# 2533  2817       Isaiah Tucker  31/07/17              shot     vehicle 28.00
# 2534  2815        Dwayne Jeune  31/07/17              shot       knife 32.00
#
#      gender race           city state  signs_of_mental_illness threat_level  \
# 0         M    A        Shelton    WA                     True       attack
# 1         M    W          Aloha    OR                    False       attack
# 2         M    H        Wichita    KS                    False        other
# 3         M    W  San Francisco    CA                     True       attack
# 4         M    H          Evans    CO                    False       attack
# ...     ...  ...            ...   ...                      ...          ...
# 2530      M  NaN    Kansas City    MO                    False       attack
# 2531      M  NaN    Albuquerque    NM                    False       attack
# 2532      M  NaN          Melba    ID                    False       attack
# 2533      M    B        Oshkosh    WI                    False       attack
# 2534      M    B       Brooklyn    NY                     True       attack
#
#              flee  body_camera
# 0     Not fleeing        False
# 1     Not fleeing        False
# 2     Not fleeing        False
# 3     Not fleeing        False
# 4     Not fleeing        False
# ...           ...          ...
# 2530  Not fleeing        False
# 2531          Car        False
# 2532          Car        False
# 2533          Car         True
# 2534  Not fleeing        False
#
# [2535 rows x 14 columns]

# %% [markdown]
# # Preliminary Data Exploration

# %%
df_pct_poverty.shape
# Out:
# (29329, 3)

# %%
df_pct_poverty.isna().values.any()
# Out:
# False

# %%
df_share_race_city.isna().values.any()
# Out:
# False

# %%
df_pct_poverty.duplicated().value_counts()
df_share_race_city.duplicated().value_counts()
# Out:
# False    29266
# dtype: int64

# %% [markdown]
# ## Data Cleaning - Check for Missing Values and Duplicates

# %%
df_pct_poverty['poverty_rate'] = df_pct_poverty['poverty_rate'].str.replace('-','0')

# %%
df_pct_completed_hs['percent_completed_hs']= df_pct_completed_hs['percent_completed_hs'].str.replace('-','0')

# %%
df_pct_poverty['poverty_rate'] =pd.to_numeric(df_pct_poverty['poverty_rate'])
df_pct_completed_hs['percent_completed_hs'] = pd.to_numeric(df_pct_completed_hs['percent_completed_hs'])

# %% [markdown]
# # Poverty Rate in each US State

# %%
df_pct_poverty
# Out:
#       Geographic Area                    City  poverty_rate
# 0                  AL              Abanda CDP         78.80
# 1                  AL          Abbeville city         29.10
# 2                  AL         Adamsville city         25.50
# 3                  AL            Addison town         30.70
# 4                  AL              Akron town         42.00
# ...               ...                     ...           ...
# 29324              WY  Woods Landing-Jelm CDP         18.60
# 29325              WY            Worland city         15.30
# 29326              WY             Wright town          5.90
# 29327              WY              Yoder town          5.40
# 29328              WY           Y-O Ranch CDP          0.00
#
# [29329 rows x 3 columns]

# %%
poverty =df_pct_poverty[['Geographic Area', 'poverty_rate']].groupby(['Geographic Area']).mean()
poverty
# Out:
#                  poverty_rate
# Geographic Area
# AK                      18.68
# AL                      20.61
# AR                      22.96
# AZ                      25.27
# CA                      16.89
# CO                      13.19
# CT                       9.14
# DC                      18.00
# DE                      12.56
# FL                      17.51
# GA                      23.66
# HI                      13.40
# IA                      12.23
# ID                      18.08
# IL                      13.85
# IN                      15.50
# KS                      14.72
# KY                      20.08
# LA                      22.29
# MA                       9.55
# MD                      10.27
# ME                      16.89
# MI                      17.90
# MN                      13.75
# MO                      19.93
# MS                      26.88
# MT                      16.42
# NC                      19.72
# ND                      12.13
# NE                      12.92
# NH                      12.66
# NJ                       8.16
# NM                      22.51
# NV                      12.37
# NY                      11.64
# OH                      14.83
# OK                      20.55
# OR                      16.44
# PA                      12.49
# RI                      10.37
# SC                      22.11
# SD                      15.75
# TN                      19.89
# TX                      19.50
# UT                      11.72
# VA                      14.59
# VT                      13.79
# WA                      14.83
# WI                      12.86
# WV                      21.08
# WY                       9.06

# %%
poverty_rate_mean = poverty['poverty_rate'].mean()
poverty_rate_mean
# Out:
# 16.120463328065163

# %%
plt.figure(figsize=(15,10))
sns.barplot(data=df_pct_poverty, x='Geographic Area', y='poverty_rate')
plt.xlabel('Geographic Area',fontsize=14)
plt.ylabel('Poverty Rate',fontsize=14)
plt.xticks(fontsize=12,rotation=45);
plt.axhline(y=poverty_rate_mean, ls='--', lw='3') # poverty_rate_mean with dotted line

# %% [markdown]
# # Chart the High School Graduation Rate by US State

# %%
df_pct_completed_hs # High School Graduation Rate US States
# Out:
#       Geographic Area                    City  percent_completed_hs
# 0                  AL              Abanda CDP                 21.20
# 1                  AL          Abbeville city                 69.10
# 2                  AL         Adamsville city                 78.90
# 3                  AL            Addison town                 81.40
# 4                  AL              Akron town                 68.60
# ...               ...                     ...                   ...
# 29324              WY  Woods Landing-Jelm CDP                100.00
# 29325              WY            Worland city                 85.60
# 29326              WY             Wright town                 89.20
# 29327              WY              Yoder town                 79.40
# 29328              WY           Y-O Ranch CDP                100.00
#
# [29329 rows x 3 columns]

# %%
df_pct_completed_hs.sort_values('percent_completed_hs') # High School Graduation Rate in ascending order of US States
# Out:
#       Geographic Area                 City  percent_completed_hs
# 25237              TX            Indio CDP                  0.00
# 25464              TX        Los Lobos CDP                  0.00
# 25457              TX   Los Corralitos CDP                  0.00
# 25456              TX  Los Centenarios CDP                  0.00
# 25452              TX      Los Angeles CDP                  0.00
# ...               ...                  ...                   ...
# 3826               CO          Sawpit town                100.00
# 23916              SD            Lily town                100.00
# 23920              SD           Loomis CDP                100.00
# 3820               CO       St. Mary's CDP                100.00
# 29328              WY        Y-O Ranch CDP                100.00
#
# [29329 rows x 3 columns]

# %%
high_school=df_pct_completed_hs[['Geographic Area', 'percent_completed_hs']].groupby(['Geographic Area']).mean()
high_school.sort_values('percent_completed_hs', ascending= False) # High School Graduation Rate grouped by US States
# Out:
#                  percent_completed_hs
# Geographic Area
# MA                              92.03
# HI                              91.67
# CT                              91.59
# ME                              91.43
# NH                              90.71
# NY                              90.54
# NJ                              90.52
# WI                              90.26
# MT                              89.99
# VT                              89.98
# IA                              89.67
# UT                              89.64
# NE                              89.52
# MN                              89.47
# DC                              89.30
# MI                              89.21
# PA                              88.97
# CO                              88.93
# RI                              88.83
# DE                              88.52
# IL                              88.29
# OH                              88.20
# MD                              88.08
# KS                              87.97
# OR                              87.60
# ND                              87.60
# WA                              87.07
# NV                              87.05
# IN                              86.32
# SD                              86.18
# FL                              85.46
# VA                              84.88
# ID                              84.42
# WY                              83.97
# NC                              83.14
# MO                              82.79
# OK                              82.46
# KY                              82.22
# WV                              82.14
# TN                              81.63
# CA                              80.82
# SC                              80.65
# AL                              80.16
# AK                              80.10
# AR                              79.95
# AZ                              79.22
# LA                              79.12
# NM                              78.97
# GA                              78.63
# MS                              78.47
# TX                              74.09

# %%
state = high_school['percent_completed_hs'].idxmax()
percentage = high_school['percent_completed_hs'].max()
print(f'The Highest Graduation Rate is {round(percentage,2)} in {state} State of US.')
# Out:
# The Highest Graduation Rate is 92.03 in MA State of US.

# %%
state = high_school['percent_completed_hs'].idxmin()
percentage = high_school['percent_completed_hs'].min()
print(f'The Highest Graduation Rate is {round(percentage,2)} in {state} State of US.')
# Out:
# The Highest Graduation Rate is 74.09 in TX State of US.

# %% [markdown]
# # Visualise the Relationship between Poverty Rates and High School Graduation Rates

# %%
poverty
# Out:
#                  poverty_rate
# Geographic Area
# AK                      18.68
# AL                      20.61
# AR                      22.96
# AZ                      25.27
# CA                      16.89
# CO                      13.19
# CT                       9.14
# DC                      18.00
# DE                      12.56
# FL                      17.51
# GA                      23.66
# HI                      13.40
# IA                      12.23
# ID                      18.08
# IL                      13.85
# IN                      15.50
# KS                      14.72
# KY                      20.08
# LA                      22.29
# MA                       9.55
# MD                      10.27
# ME                      16.89
# MI                      17.90
# MN                      13.75
# MO                      19.93
# MS                      26.88
# MT                      16.42
# NC                      19.72
# ND                      12.13
# NE                      12.92
# NH                      12.66
# NJ                       8.16
# NM                      22.51
# NV                      12.37
# NY                      11.64
# OH                      14.83
# OK                      20.55
# OR                      16.44
# PA                      12.49
# RI                      10.37
# SC                      22.11
# SD                      15.75
# TN                      19.89
# TX                      19.50
# UT                      11.72
# VA                      14.59
# VT                      13.79
# WA                      14.83
# WI                      12.86
# WV                      21.08
# WY                       9.06

# %%
high_school
# Out:
#                  percent_completed_hs
# Geographic Area
# AK                              80.10
# AL                              80.16
# AR                              79.95
# AZ                              79.22
# CA                              80.82
# CO                              88.93
# CT                              91.59
# DC                              89.30
# DE                              88.52
# FL                              85.46
# GA                              78.63
# HI                              91.67
# IA                              89.67
# ID                              84.42
# IL                              88.29
# IN                              86.32
# KS                              87.97
# KY                              82.22
# LA                              79.12
# MA                              92.03
# MD                              88.08
# ME                              91.43
# MI                              89.21
# MN                              89.47
# MO                              82.79
# MS                              78.47
# MT                              89.99
# NC                              83.14
# ND                              87.60
# NE                              89.52
# NH                              90.71
# NJ                              90.52
# NM                              78.97
# NV                              87.05
# NY                              90.54
# OH                              88.20
# OK                              82.46
# OR                              87.60
# PA                              88.97
# RI                              88.83
# SC                              80.65
# SD                              86.18
# TN                              81.63
# TX                              74.09
# UT                              89.64
# VA                              84.88
# VT                              89.98
# WA                              87.07
# WI                              90.26
# WV                              82.14
# WY                              83.97

# %%
plt.figure(figsize=(15,10))
plt.plot(poverty.index,poverty['poverty_rate'] )
plt.plot(high_school.index, high_school['percent_completed_hs']) 

# line chart with two y-axes to show if the rations of poverty and high school graduation move together.

# %%
plt.figure(figsize=(15,10))
ax1= plt.gca() # current_axis
ax2= ax1.twinx()
ax1.plot(poverty.index,poverty['poverty_rate'] ,color ='red')
ax2.plot(high_school.index, high_school['percent_completed_hs'], color='blue')

#rations of poverty and high school graduation move together BUT in inverse direction

# %%
merged_p_hs = pd.merge(poverty, high_school, on='Geographic Area', how='inner') 
merged_p_hs # merged Poverty Rate and High School Graduate
# Out:
#                  poverty_rate  percent_completed_hs
# Geographic Area
# AK                      18.68                 80.10
# AL                      20.61                 80.16
# AR                      22.96                 79.95
# AZ                      25.27                 79.22
# CA                      16.89                 80.82
# CO                      13.19                 88.93
# CT                       9.14                 91.59
# DC                      18.00                 89.30
# DE                      12.56                 88.52
# FL                      17.51                 85.46
# GA                      23.66                 78.63
# HI                      13.40                 91.67
# IA                      12.23                 89.67
# ID                      18.08                 84.42
# IL                      13.85                 88.29
# IN                      15.50                 86.32
# KS                      14.72                 87.97
# KY                      20.08                 82.22
# LA                      22.29                 79.12
# MA                       9.55                 92.03
# MD                      10.27                 88.08
# ME                      16.89                 91.43
# MI                      17.90                 89.21
# MN                      13.75                 89.47
# MO                      19.93                 82.79
# MS                      26.88                 78.47
# MT                      16.42                 89.99
# NC                      19.72                 83.14
# ND                      12.13                 87.60
# NE                      12.92                 89.52
# NH                      12.66                 90.71
# NJ                       8.16                 90.52
# NM                      22.51                 78.97
# NV                      12.37                 87.05
# NY                      11.64                 90.54
# OH                      14.83                 88.20
# OK                      20.55                 82.46
# OR                      16.44                 87.60
# PA                      12.49                 88.97
# RI                      10.37                 88.83
# SC                      22.11                 80.65
# SD                      15.75                 86.18
# TN                      19.89                 81.63
# TX                      19.50                 74.09
# UT                      11.72                 89.64
# VA                      14.59                 84.88
# VT                      13.79                 89.98
# WA                      14.83                 87.07
# WI                      12.86                 90.26
# WV                      21.08                 82.14
# WY                       9.06                 83.97

# %% [markdown]
# #### Scatter plot with a Kernel Density Estimate (KDE)  to visualise the same relationship

# %%
plt.figure(figsize=(15,10))
sns.jointplot(data=merged_p_hs, x='poverty_rate', y='percent_completed_hs',color='brown')

# %% [markdown]
# #### Linear regression between the poverty ratio and the high school graduation ratio.

# %%
plt.figure(figsize=(15,10))
sns.lmplot(data=merged_p_hs, x='poverty_rate', y='percent_completed_hs')

# %%
plt.figure(figsize=(15,10),dpi=300)
with sns.axes_style('whitegrid') as ax:
    ax=sns.regplot(data=merged_p_hs, x='poverty_rate', y='percent_completed_hs',scatter_kws={'alpha':0.7},line_kws={'color':'red'})
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('Poverty Rate %',fontsize=14)
plt.ylabel('High School %',fontsize=14)
# Out:
# Text(0, 0.5, 'High School %')

# %% [markdown]
# # Bar Chart with Subsections Showing the Racial Makeup of Each US State
#
# Visualise the share of the white, black, hispanic, asian and native american population in each US State using a bar chart with sub sections.

# %%
df_share_race_city.describe()
# Out:
#        share_white  share_black  share_native_american  share_asian  \
# count    29,266.00    29,266.00              29,266.00    29,266.00
# mean         83.16         6.83                   2.87         1.54
# std          21.75        15.62                  12.67         4.29
# min           0.00         0.00                   0.00         0.00
# 25%          78.50         0.10                   0.10         0.00
# 50%          92.50         0.80                   0.30         0.40
# 75%          96.90         4.20                   0.90         1.20
# max         100.00       100.00                 100.00        67.10
#
#        share_hispanic
# count       29,266.00
# mean             9.32
# std             17.58
# min              0.00
# 25%              1.20
# 50%              2.90
# 75%              8.00
# max            100.00

# %%
race_city=df_share_race_city.groupby(['Geographic area']).sum()
race_city
# Out:
#                  share_white  share_black  share_native_american  share_asian  \
# Geographic area
# AK                 16,068.80       199.70              16,144.40       488.70
# AL                 41,909.20    13,480.30                 381.10       277.30
# AR                 42,441.20     8,816.60                 411.10       258.10
# AZ                 27,028.00       430.50              12,894.00       327.70
# CA                108,949.30     4,081.10               2,612.20     8,441.40
# CO                 40,197.90       420.30                 744.20       528.90
# CT                 12,313.10       713.90                  93.90       427.50
# DC                     38.50        50.70                   0.30         3.50
# DE                  5,794.70     1,169.90                  39.80       152.00
# FL                 72,378.70    12,301.20                 419.00     1,487.40
# GA                 39,182.30    19,176.60                 188.00       933.70
# HI                  5,038.80       161.70                  58.60     3,873.90
# IA                 97,576.20       568.60                 273.80       404.40
# ID                 20,161.60        67.00                 573.10       110.70
# IL                123,518.10     6,430.80                 357.90     1,828.30
# IN                 64,669.90     1,151.40                 188.10       400.20
# KS                 62,377.90       644.50               1,256.90       286.10
# KY                 48,419.10     2,321.10                 110.30       373.30
# LA                 30,657.30    14,556.80                 452.80       372.00
# MA                 21,790.30       680.90                  64.70       693.40
# MD                 37,356.30    10,082.30                 176.60     1,543.70
# ME                 12,534.90       107.40                  71.40       135.20
# MI                 62,744.70     2,854.00                 745.30       660.30
# MN                 83,171.00       906.70               3,047.00       929.30
# MO                 93,066.80     6,049.90                 560.10       565.80
# MS                 19,475.60    15,143.90                 584.50       197.70
# MT                 30,833.70        82.70               4,332.90       116.40
# NC                 52,850.70    15,077.30               1,321.40       684.50
# ND                 37,009.80       143.30               2,137.30       117.70
# NE                 54,936.20       243.90                 904.70       169.30
# NH                  9,185.40        68.70                  27.60       128.90
# NJ                 44,084.80     3,801.40                 140.10     3,239.90
# NM                 28,980.40       295.50               6,795.80       218.80
# NV                 10,620.10       202.20                 719.40       258.90
# NY                105,676.30     4,765.20                 429.60     3,233.30
# OH                111,736.10     4,767.80                 258.90       904.80
# OK                 53,454.60     2,474.80              10,542.10       312.60
# OR                 32,947.20       199.10                 973.30       519.80
# PA                164,498.70     5,768.70                 285.00     1,744.60
# RI                  3,033.70       101.60                  22.80        57.40
# SC                 24,480.40    12,969.60                 182.80       292.30
# SD                 33,078.90       113.10               4,690.40       124.00
# TN                 38,158.30     3,132.90                 135.80       273.40
# TX                144,370.70    10,277.80               1,151.70     1,773.80
# UT                 29,158.50       125.50               1,261.70       251.30
# VA                 44,086.90     9,757.90                 202.30     2,168.40
# VT                 11,408.10        91.70                  44.00       108.30
# WA                 51,732.10       895.90               2,355.20     1,930.80
# WI                 71,858.50       724.50               2,025.50       611.30
# WV                 38,109.20     1,169.00                  80.30       136.80
# WY                 18,659.50        80.70                 625.20        78.70
#
#                  share_hispanic
# Geographic area
# AK                       756.50
# AL                     1,722.50
# AR                     2,311.70
# AZ                     9,085.20
# CA                    44,949.20
# CO                     8,197.60
# CT                     1,140.50
# DC                         9.10
# DE                       563.70
# FL                    15,206.80
# GA                     4,015.90
# HI                     1,564.10
# IA                     2,844.40
# ID                     2,427.80
# IL                     7,068.10
# IN                     2,263.00
# KS                     3,403.10
# KY                     1,168.40
# LA                     1,407.90
# MA                     1,201.90
# MD                     3,072.50
# ME                       172.00
# MI                     2,446.50
# MN                     2,857.40
# MO                     2,433.40
# MS                       840.50
# MT                       800.10
# NC                     4,739.10
# ND                       731.00
# NE                     2,360.70
# NH                       167.50
# NJ                     6,062.00
# NM                    20,127.50
# NV                     1,699.40
# NY                     7,882.10
# OH                     2,565.00
# OK                     4,175.50
# OR                     3,676.10
# PA                     4,820.20
# RI                       226.70
# SC                     1,767.80
# SD                       794.40
# TN                     1,225.30
# TX                    68,809.80
# UT                     2,498.20
# VA                     3,636.40
# VT                       164.20
# WA                     6,662.10
# WI                     2,568.90
# WV                       362.60
# WY                     1,215.60

# %%
fig = px.bar(race_city,width=1000,height=500,) # Total share of race per city
fig.update_xaxes(tickangle = -45)
fig.show()

# %% [markdown]
# # Donut Chart by of People Killed by Race

# %%
df_fatalities.head()
# Out:
#    id                name      date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  2/1/2015              shot         gun 53.00
# 1   4    Lewis Lee Lembke  2/1/2015              shot         gun 47.00
# 2   5  John Paul Quintero  3/1/2015  shot and Tasered     unarmed 23.00
# 3   8     Matthew Hoffman  4/1/2015              shot  toy weapon 32.00
# 4   9   Michael Rodriguez  4/1/2015              shot    nail gun 39.00
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera
# 0  Not fleeing        False
# 1  Not fleeing        False
# 2  Not fleeing        False
# 3  Not fleeing        False
# 4  Not fleeing        False

# %%
df_fatalities['race_name'] = df_fatalities['race'].map({'A':'Asian',
                                                        'B':'Black',
                                                        'H':'Hispanic',
                                                        'W':'White', 
                                                        'N':'Native American',
                                                        'O': 'Others'
                                                       })
df_fatalities
# Out:
#         id                name      date   manner_of_death       armed   age  \
# 0        3          Tim Elliot  2/1/2015              shot         gun 53.00
# 1        4    Lewis Lee Lembke  2/1/2015              shot         gun 47.00
# 2        5  John Paul Quintero  3/1/2015  shot and Tasered     unarmed 23.00
# 3        8     Matthew Hoffman  4/1/2015              shot  toy weapon 32.00
# 4        9   Michael Rodriguez  4/1/2015              shot    nail gun 39.00
# ...    ...                 ...       ...               ...         ...   ...
# 2530  2822    Rodney E. Jacobs  28/07/17              shot         gun 31.00
# 2531  2813               TK TK  28/07/17              shot     vehicle   NaN
# 2532  2818  Dennis W. Robinson  29/07/17              shot         gun 48.00
# 2533  2817       Isaiah Tucker  31/07/17              shot     vehicle 28.00
# 2534  2815        Dwayne Jeune  31/07/17              shot       knife 32.00
#
#      gender race           city state  signs_of_mental_illness threat_level  \
# 0         M    A        Shelton    WA                     True       attack
# 1         M    W          Aloha    OR                    False       attack
# 2         M    H        Wichita    KS                    False        other
# 3         M    W  San Francisco    CA                     True       attack
# 4         M    H          Evans    CO                    False       attack
# ...     ...  ...            ...   ...                      ...          ...
# 2530      M  NaN    Kansas City    MO                    False       attack
# 2531      M  NaN    Albuquerque    NM                    False       attack
# 2532      M  NaN          Melba    ID                    False       attack
# 2533      M    B        Oshkosh    WI                    False       attack
# 2534      M    B       Brooklyn    NY                     True       attack
#
#              flee  body_camera race_name
# 0     Not fleeing        False     Asian
# 1     Not fleeing        False     White
# 2     Not fleeing        False  Hispanic
# 3     Not fleeing        False     White
# 4     Not fleeing        False  Hispanic
# ...           ...          ...       ...
# 2530  Not fleeing        False       NaN
# 2531          Car        False       NaN
# 2532          Car        False       NaN
# 2533          Car         True     Black
# 2534  Not fleeing        False     Black
#
# [2535 rows x 15 columns]

# %%
killed_by_race=df_fatalities['race_name'].value_counts()
killed_by_race
# Out:
# White              1201
# Black               618
# Hispanic            423
# Asian                39
# Native American      31
# Others               28
# Name: race_name, dtype: int64

# %%
px.pie(killed_by_race, names=killed_by_race.index, values=killed_by_race.values,hole=0.5)

# %% [markdown]
# # Chart Comparing the Total Number of Deaths of Men and Women

# %%
df_fatalities['gender'].value_counts()
# Out:
# M    2428
# F     107
# Name: gender, dtype: int64

# %% [markdown]
# # Box Plot Showing the Age and Manner of Death
# #### Is there a difference between men and women in the manner of death?

# %%
df_fatalities=df_fatalities.dropna()

# %%
df_fatalities.isna().values.any()
# Out:
# False

# %%
df_fatalities
# Out:
#         id                name      date   manner_of_death         armed  \
# 0        3          Tim Elliot  2/1/2015              shot           gun
# 1        4    Lewis Lee Lembke  2/1/2015              shot           gun
# 2        5  John Paul Quintero  3/1/2015  shot and Tasered       unarmed
# 3        8     Matthew Hoffman  4/1/2015              shot    toy weapon
# 4        9   Michael Rodriguez  4/1/2015              shot      nail gun
# ...    ...                 ...       ...               ...           ...
# 2519  2805         Aries Clark  25/07/17              shot  undetermined
# 2523  2808   Kesharn K. Burney  26/07/17              shot       vehicle
# 2525  2820    Deltra Henderson  27/07/17              shot           gun
# 2533  2817       Isaiah Tucker  31/07/17              shot       vehicle
# 2534  2815        Dwayne Jeune  31/07/17              shot         knife
#
#        age gender race           city state  signs_of_mental_illness  \
# 0    53.00      M    A        Shelton    WA                     True
# 1    47.00      M    W          Aloha    OR                    False
# 2    23.00      M    H        Wichita    KS                    False
# 3    32.00      M    W  San Francisco    CA                     True
# 4    39.00      M    H          Evans    CO                    False
# ...    ...    ...  ...            ...   ...                      ...
# 2519 16.00      M    B         Marion    AR                    False
# 2523 25.00      M    B         Dayton    OH                    False
# 2525 39.00      M    B          Homer    LA                    False
# 2533 28.00      M    B        Oshkosh    WI                    False
# 2534 32.00      M    B       Brooklyn    NY                     True
#
#       threat_level         flee  body_camera race_name
# 0           attack  Not fleeing        False     Asian
# 1           attack  Not fleeing        False     White
# 2            other  Not fleeing        False  Hispanic
# 3           attack  Not fleeing        False     White
# 4           attack  Not fleeing        False  Hispanic
# ...            ...          ...          ...       ...
# 2519  undetermined  Not fleeing        False     Black
# 2523        attack          Car        False     Black
# 2525        attack          Car        False     Black
# 2533        attack          Car         True     Black
# 2534        attack  Not fleeing        False     Black
#
# [2254 rows x 15 columns]

# %%
male_death=df_fatalities[df_fatalities['gender']=='M']

# %%
female_death=df_fatalities[df_fatalities['gender']=='F']

# %%
death_manners = df_fatalities.groupby(['gender','manner_of_death', 'age'],as_index=False).agg({'id':pd.Series.count})
death_manners
# Out:
#     gender   manner_of_death   age  id
# 0        F              shot 12.00   1
# 1        F              shot 17.00   3
# 2        F              shot 20.00   1
# 3        F              shot 21.00   3
# 4        F              shot 22.00   1
# ..     ...               ...   ...  ..
# 158      M  shot and Tasered 60.00   1
# 159      M  shot and Tasered 63.00   3
# 160      M  shot and Tasered 67.00   1
# 161      M  shot and Tasered 70.00   1
# 162      M  shot and Tasered 76.00   1
#
# [163 rows x 4 columns]

# %%
px.box(death_manners, y="age", x="gender", color="manner_of_death")

# %% [markdown]
# # Were People Armed?
#
# In what percentage of police killings were people armed? Create chart that show what kind of weapon (if any) the deceased was carrying.

# %%
df_fatalities.head()
# Out:
#    id                name      date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  2/1/2015              shot         gun 53.00
# 1   4    Lewis Lee Lembke  2/1/2015              shot         gun 47.00
# 2   5  John Paul Quintero  3/1/2015  shot and Tasered     unarmed 23.00
# 3   8     Matthew Hoffman  4/1/2015              shot  toy weapon 32.00
# 4   9   Michael Rodriguez  4/1/2015              shot    nail gun 39.00
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera race_name
# 0  Not fleeing        False     Asian
# 1  Not fleeing        False     White
# 2  Not fleeing        False  Hispanic
# 3  Not fleeing        False     White
# 4  Not fleeing        False  Hispanic

# %% [markdown]
# #### How many of the people killed by police were armed with guns versus unarmed?

# %%
armed_df = df_fatalities[(df_fatalities.armed == 'gun') | (df_fatalities.armed=='unarmed')]
gun_vs_armed = armed_df.groupby('armed', as_index=False).agg({'id':pd.Series.count})
gun_vs_armed
# Out:
#      armed    id
# 0      gun  1247
# 1  unarmed   165

# %%
plt.figure(figsize=(8,6),dpi=100)
sns.barplot(data=gun_vs_armed, x='armed',y='id')
plt.xticks(fontsize=12)
plt.xlabel('Armed or Not',fontsize=12)
plt.ylabel('No. of People Killed',fontsize=12)
# Out:
# Text(0, 0.5, 'No. of People Killed')

# %% [markdown]
# # How Old Were the People Killed?

# %% [markdown]
# Work out what percentage of people killed were under 25 years old.

# %%
under25 = df_fatalities[df_fatalities['age']<25].count().id
print(f'There were {under25} people killed which were under 25 years old')
# Out:
# There were 422 people killed which were under 25 years old

# %%
over25 = df_fatalities[df_fatalities['age']>=25].count().id
print(f'There were {over25} people killed which were over 25 years old')
# Out:
# There were 1832 people killed which were over 25 years old

# %%
total_people_by_age = under25 + over25
total_people_by_age
# Out:
# 2254

# %%
under_25_pct = round(under25 / total_people_by_age *100)
print(f'The percentage of people killed were under 25 years old is {under_25_pct}%')
# Out:
# The percentage of people killed were under 25 years old is 19%

# %%
over_25_pct = round(over25 / total_people_by_age *100)
print(f'The percentage of people killed were over 25 years old is {over_25_pct}%')
# Out:
# The percentage of people killed were over 25 years old is 81%

# %% [markdown]
# #### Create a histogram and KDE plot that shows the distribution of ages of the people killed by police.

# %%
df_fatalities.head()
# Out:
#    id                name      date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  2/1/2015              shot         gun 53.00
# 1   4    Lewis Lee Lembke  2/1/2015              shot         gun 47.00
# 2   5  John Paul Quintero  3/1/2015  shot and Tasered     unarmed 23.00
# 3   8     Matthew Hoffman  4/1/2015              shot  toy weapon 32.00
# 4   9   Michael Rodriguez  4/1/2015              shot    nail gun 39.00
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera race_name
# 0  Not fleeing        False     Asian
# 1  Not fleeing        False     White
# 2  Not fleeing        False  Hispanic
# 3  Not fleeing        False     White
# 4  Not fleeing        False  Hispanic

# %%
age_0plus = df_fatalities[df_fatalities['age']>0]
age_0plus
# Out:
#         id                name      date   manner_of_death         armed  \
# 0        3          Tim Elliot  2/1/2015              shot           gun
# 1        4    Lewis Lee Lembke  2/1/2015              shot           gun
# 2        5  John Paul Quintero  3/1/2015  shot and Tasered       unarmed
# 3        8     Matthew Hoffman  4/1/2015              shot    toy weapon
# 4        9   Michael Rodriguez  4/1/2015              shot      nail gun
# ...    ...                 ...       ...               ...           ...
# 2519  2805         Aries Clark  25/07/17              shot  undetermined
# 2523  2808   Kesharn K. Burney  26/07/17              shot       vehicle
# 2525  2820    Deltra Henderson  27/07/17              shot           gun
# 2533  2817       Isaiah Tucker  31/07/17              shot       vehicle
# 2534  2815        Dwayne Jeune  31/07/17              shot         knife
#
#        age gender race           city state  signs_of_mental_illness  \
# 0    53.00      M    A        Shelton    WA                     True
# 1    47.00      M    W          Aloha    OR                    False
# 2    23.00      M    H        Wichita    KS                    False
# 3    32.00      M    W  San Francisco    CA                     True
# 4    39.00      M    H          Evans    CO                    False
# ...    ...    ...  ...            ...   ...                      ...
# 2519 16.00      M    B         Marion    AR                    False
# 2523 25.00      M    B         Dayton    OH                    False
# 2525 39.00      M    B          Homer    LA                    False
# 2533 28.00      M    B        Oshkosh    WI                    False
# 2534 32.00      M    B       Brooklyn    NY                     True
#
#       threat_level         flee  body_camera race_name
# 0           attack  Not fleeing        False     Asian
# 1           attack  Not fleeing        False     White
# 2            other  Not fleeing        False  Hispanic
# 3           attack  Not fleeing        False     White
# 4           attack  Not fleeing        False  Hispanic
# ...            ...          ...          ...       ...
# 2519  undetermined  Not fleeing        False     Black
# 2523        attack          Car        False     Black
# 2525        attack          Car        False     Black
# 2533        attack          Car         True     Black
# 2534        attack  Not fleeing        False     Black
#
# [2254 rows x 15 columns]

# %%
age_killed=age_0plus.groupby(['age'],as_index=False).agg({'id':pd.Series.count})
age_killed
# Out:
#      age  id
# 0   6.00   1
# 1  12.00   1
# 2  13.00   1
# 3  14.00   1
# 4  15.00   7
# ..   ...  ..
# 67 79.00   1
# 68 80.00   1
# 69 82.00   1
# 70 83.00   2
# 71 91.00   1
#
# [72 rows x 2 columns]

# %%
sns.jointplot(data=age_killed, x='age',y='id',kind='kde',shade=True)

# %% [markdown]
# #### Create a seperate KDE plot for each race. Is there a difference between the distributions?

# %%
race_death = df_fatalities.groupby(['race_name','age'],as_index=False).agg({'id':pd.Series.count})
race_death
# Out:
#     race_name   age  id
# 0       Asian 15.00   1
# 1       Asian 18.00   2
# 2       Asian 20.00   1
# 3       Asian 25.00   1
# 4       Asian 26.00   1
# ..        ...   ...  ..
# 237     White 76.00   4
# 238     White 79.00   1
# 239     White 82.00   1
# 240     White 83.00   2
# 241     White 91.00   1
#
# [242 rows x 3 columns]

# %%
plt.figure(figsize=(6,4),dpi=100)
race_death_W = race_death[race_death['race_name']=="White"]
sns.kdeplot(x=race_death_W['age'], y= race_death_W['id'], shade=True, cmap='viridis',alpha=0.6)
plt.ylim(0,70)
plt.xlim(0,100)
plt.xlabel('Age',fontsize=12)
plt.ylabel('No. of People White Killed',fontsize=12);

# %%
plt.figure(figsize=(6,4),dpi=100)
race_death_B = race_death[race_death['race_name']=="Black"]
sns.kdeplot(x=race_death_B['age'], y= race_death_B['id'], shade=True, cmap='viridis',alpha=0.6)
plt.ylim(0,50)
plt.xlim(0,100)
plt.xlabel('Age',fontsize=12)
plt.ylabel('No. of People Black Killed',fontsize=12);

# %%
plt.figure(figsize=(6,4),dpi=100)
race_death_A = race_death[race_death['race_name']=="Asian"]
sns.kdeplot(x=race_death_A['age'], y= race_death_A['id'], shade=True, cmap='viridis',alpha=0.6)
plt.ylim(0,4)
plt.xlim(0,100)
plt.xlabel('Age',fontsize=12)
plt.ylabel('No. of People Asian Killed',fontsize=12);

# %%
plt.figure(figsize=(6,4),dpi=100)
race_death_H = race_death[race_death['race_name']=="Hispanic"]
sns.kdeplot(x=race_death_H['age'], y= race_death_H['id'], shade=True, cmap='viridis',alpha=0.6)
plt.ylim(0,25)
plt.xlim(0,100)
plt.xlabel('Age',fontsize=12)
plt.ylabel('No. of People Hispanic Killed',fontsize=12);

# %% [markdown]
# # Race of People Killed
#
# Create a chart that shows the total number of people killed by race.

# %%
killed_by_race = df_fatalities.groupby(['race_name'],as_index=False).agg({'id':pd.Series.count}).sort_values('id')
killed_by_race
# Out:
#          race_name    id
# 4           Others    28
# 3  Native American    29
# 0            Asian    36
# 2         Hispanic   401
# 1            Black   592
# 5            White  1168

# %%
sns.barplot(data=killed_by_race, x='race_name', y=killed_by_race['id'],palette='summer')
plt.xlabel('Race',fontsize=12);
plt.ylabel('No. of People  Killed',fontsize=12);

# %% [markdown]
# # In Which Cities Do the Most Police Killings Take Place?
#
# #### Top 10 cities with the most police killings. Which cities are the most dangerous?

# %%
killing_by_cities = df_fatalities.groupby(['city'],as_index=False).agg({'id':pd.Series.count}).sort_values('id',ascending=True)[-10:]
killing_by_cities.columns=['City', 'No of People Killed']
killing_by_cities
# Out:
#              City  No of People Killed
# 1095    St. Louis                   14
# 723         Miami                   15
# 1003  San Antonio                   15
# 254      Columbus                   16
# 619     Las Vegas                   17
# 57         Austin                   18
# 212       Chicago                   22
# 518       Houston                   24
# 895       Phoenix                   28
# 658   Los Angeles                   35

# %%
plt.figure(figsize=(12,8),dpi=100)
sns.barplot(data= killing_by_cities,x='City', y='No of People Killed',palette='RdBu' )
# Out:
# <AxesSubplot:xlabel='City', ylabel='No of People Killed'>

# %% [markdown]
# # Number of Police Killings Over Time
#
# Analyse the Number of Police Killings over Time

# %%
df_fatalities['date'] = pd.to_datetime(df_fatalities['date'])
# Out:
# <ipython-input-71-ea1695318982>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
type(df_fatalities['date'])
# Out:
# pandas.core.series.Series

# %%
killing_over_time=df_fatalities.groupby('date',as_index=False).agg({'id':pd.Series.count})
killing_over_time
# Out:
#           date  id
# 0   2015-01-03   3
# 1   2015-01-04   2
# 2   2015-01-06   1
# 3   2015-01-07   2
# 4   2015-01-08   1
# ..         ...  ..
# 841 2017-12-02   2
# 842 2017-12-03   2
# 843 2017-12-04   1
# 844 2017-12-05   3
# 845 2017-12-06   4
#
# [846 rows x 2 columns]

# %%
killing_over_time_ma = killing_over_time['id'].rolling(window=180).mean() # Moving Average of 180 days

# %%
px.line(x=killing_over_time['date'],y=killing_over_time_ma)

# %% [markdown]
# # Result
# ***Police Killing trend is Downward from so many years***

# %% [markdown]
# # Choropleth Map of Police Killings by US State

# %%
killing_by_states = df_fatalities.groupby(['state'],as_index=False).agg({'id':pd.Series.count}).sort_values('id',ascending=False)
killing_by_states.columns=['State', 'No of People Killed']
killing_by_states
# Out:
#    State  No of People Killed
# 4     CA                  366
# 43    TX                  200
# 9     FL                  136
# 3     AZ                  105
# 35    OH                   70
# 27    NC                   66
# 36    OK                   65
# 5     CO                   63
# 10    GA                   61
# 24    MO                   58
# 42    TN                   56
# 14    IL                   56
# 47    WA                   51
# 18    LA                   47
# 38    PA                   45
# 1     AL                   45
# 45    VA                   43
# 34    NY                   43
# 48    WI                   42
# 40    SC                   41
# 32    NM                   41
# 17    KY                   40
# 15    IN                   40
# 22    MI                   36
# 20    MD                   36
# 33    NV                   34
# 37    OR                   32
# 23    MN                   31
# 31    NJ                   30
# 16    KS                   24
# 19    MA                   22
# 44    UT                   22
# 25    MS                   22
# 49    WV                   21
# 2     AR                   20
# 0     AK                   14
# 29    NE                   14
# 13    ID                   14
# 12    IA                   12
# 26    MT                   11
# 11    HI                   11
# 7     DC                   11
# 21    ME                   10
# 41    SD                    9
# 8     DE                    8
# 30    NH                    7
# 6     CT                    7
# 50    WY                    7
# 28    ND                    4
# 46    VT                    3
# 39    RI                    2

# %%
# Choropleth map with plotly.express
fig = px.choropleth(killing_by_states,
              locations='State',
              color= 'No of People Killed',
              locationmode='USA-states',
              color_continuous_scale='spectral_r',
              scope ='usa')

# Add Abbreviated State labels
fig.add_scattergeo(
    locations=killing_by_states['State'],
    locationmode='USA-states',
    text=killing_by_states['State'],
    mode='text')

# Add Title 
fig.update_layout(
    title={'text':'Police Killings by US State',
           'xanchor':'center',
           'yanchor':'top',
           'x':0.5})
fig.show()

# %% [markdown]
# # THANK YOU
